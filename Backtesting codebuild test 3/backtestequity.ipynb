# %%
import pandas as pd
import MetaTrader5 as mt5
from backtesting import Backtest, Strategy
import logging
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

# Logging configuration
logging.basicConfig(filename='backtest.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# MetaTrader 5 initialization
def init_mt5_connection(login, password, server):
    if not mt5.initialize(login=login, password=password, server=server):
        logging.error(f"initialize() failed, error code = {mt5.last_error()}")
        sys.exit()
    logging.info("Connected to MetaTrader 5")
    print("Connected to MetaTrader 5")

# Fetch historical OHLC data from MetaTrader 5
def fetch_ohlc_data(symbol, timeframe, start_date, end_date):
    data = mt5.copy_rates_range(symbol, timeframe, start_date, end_date)
    if data is None or len(data) == 0:
        logging.error(f"Failed to fetch data for {symbol}")
        return None
    ohlc_data = pd.DataFrame(data)
    ohlc_data['time'] = pd.to_datetime(ohlc_data['time'], unit='s')
    ohlc_data.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'tick_volume': 'Volume'}, inplace=True)
    return ohlc_data[['time', 'Open', 'High', 'Low', 'Close', 'Volume']]  # Include Volume

# Load and align prediction data
def load_and_align_data(ohlc_data, prediction_file):
    try:
        predictions = pd.read_csv(prediction_file, parse_dates=['time'])
        if 'prediction' not in predictions.columns:
            logging.error(f"'prediction' column not found in {prediction_file}")
            return None
    except Exception as e:
        logging.error(f"Error loading prediction file: {e}")
        return None
    # Merge predictions with OHLC data
    ohlc_data = ohlc_data.merge(predictions[['time', 'prediction']], on='time', how='left')
    ohlc_data['prediction'] = ohlc_data['prediction'].fillna(0)  # Fill missing predictions with 0
    ohlc_data['prediction'] = ohlc_data['prediction'].shift(-1)  # Shift predictions to next date
    return ohlc_data

# Backtesting strategy for Buy or Sell
class PredictionStrategy(Strategy):
    def init(self):
        pass

    def next(self):
        entry_price = self.data.Close[-1]
        risk_part, reward_part = self.risk_reward_ratio
        # Buy signal
        if self.data.prediction[-1] == 1 and self.signal_type == 'Buy':
            sl_price = entry_price - self.mean_candle_size * risk_part
            tp_price = entry_price + self.mean_candle_size * reward_part
            self.buy(sl=sl_price, tp=tp_price)
        # Sell signal
        elif self.data.prediction[-1] == 1 and self.signal_type == 'Sell':
            sl_price = entry_price + self.mean_candle_size * risk_part
            tp_price = entry_price - self.mean_candle_size * reward_part
            self.sell(sl=sl_price, tp=tp_price)

# Function to perform backtesting and save stats/plot
def run_backtest(ohlc_data, strategy_class, risk_reward_ratio, pair_name, signal_type, mean_candle_size, margin):
    strategy_class.risk_reward_ratio = risk_reward_ratio
    strategy_class.signal_type = signal_type
    strategy_class.mean_candle_size = mean_candle_size  # Set mean candle size for the strategy
    
    # Run the backtest with specified margin
    bt = Backtest(ohlc_data.set_index('time'), strategy_class, cash=10000, commission=.0003, margin=margin)
    stats = bt.run()
    
    # Plot the equity curve
    equity_curve = stats['_equity_curve']['Equity']
    
    plt.figure(figsize=(10, 6))
    plt.plot(equity_curve, label=f'Equity Curve - {pair_name} - {signal_type}')
    plt.title(f'Equity Curve for {pair_name} - {signal_type}')
    plt.xlabel('Time')
    plt.ylabel('Equity')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return stats

# Main function to fetch OHLC data, align it with prediction data, and run backtest for each buy/sell
def main():
    config = {
        'login': 51988090,
        'password': '1fMdV52$74EOcw',
        'server': 'ICMarketsEU-Demo',
        'EURUSD': {
            'symbol': 'EURUSD',
            'timeframe': mt5.TIMEFRAME_D1,
            'mean_candle_size': 0.009196304524519085,
            'buy_prediction_file': 'pred_EURUSD_Buy.csv',
            'sell_prediction_file': 'pred_EURUSD_Sell.csv',
            'buy_risk_reward_ratio': (1, 2),
            'sell_risk_reward_ratio': (1, 1),
            'margin': 0.1,
        },
        'GBPUSD': {
            'symbol': 'GBPUSD',
            'timeframe': mt5.TIMEFRAME_D1,
            'mean_candle_size': 0.011,
            'buy_prediction_file': 'pred_GBPUSD_Buy.csv',
            'sell_prediction_file': 'pred_GBPUSD_Sell.csv',
            'buy_risk_reward_ratio': (1, 2),
            'sell_risk_reward_ratio': (1, 1),
            'margin': 0.1,
        },
        'AUDUSD': {
            'symbol': 'AUDUSD',
            'timeframe': mt5.TIMEFRAME_D1,
            'mean_candle_size': 0.0080,
            'buy_prediction_file': 'pred_AUDUSD_Buy.csv',
            'sell_prediction_file': 'pred_AUDUSD_Sell.csv',
            'buy_risk_reward_ratio': (1, 2),
            'sell_risk_reward_ratio': (1, 1),
            'margin': 0.1,
        },
        'USDCHF': {
            'symbol': 'USDCHF',
            'timeframe': mt5.TIMEFRAME_D1,
            'mean_candle_size': 0.007648387882066531,
            'buy_prediction_file': 'pred_USDCHF_Buy.csv',
            'sell_prediction_file': 'pred_USDCHF_Sell.csv',
            'buy_risk_reward_ratio': (1, 2),
            'sell_risk_reward_ratio': (1, 1),
            'margin': 0.2,
        },
        'USDCAD': {
            'symbol': 'USDCAD',
            'timeframe': mt5.TIMEFRAME_D1,
            'mean_candle_size': 0.0085,
            'buy_prediction_file': 'pred_USDCAD_Buy.csv',
            'sell_prediction_file': 'pred_USDCAD_Sell.csv',
            'buy_risk_reward_ratio': (1, 1),
            'sell_risk_reward_ratio': (2, 3),
            'margin': 0.1,
        }
    }

    init_mt5_connection(config['login'], config['password'], config['server'])
    utc_from = datetime(2023, 7, 31, tzinfo=pytz.utc)
    utc_to = datetime(2024, 11, 1, tzinfo=pytz.utc)

    for pair_name, pair_config in config.items():
        if pair_name in ['login', 'password', 'server']:
            continue
        logging.info(f"Processing {pair_name}...")
        ohlc_data = fetch_ohlc_data(pair_config['symbol'], pair_config['timeframe'], utc_from, utc_to)
        if ohlc_data is None:
            continue

        if pair_config['buy_prediction_file']:
            ohlc_data_with_predictions = load_and_align_data(ohlc_data, pair_config['buy_prediction_file'])
            if ohlc_data_with_predictions is not None:
                stats = run_backtest(ohlc_data_with_predictions, PredictionStrategy, pair_config['buy_risk_reward_ratio'], pair_name, 'Buy', pair_config['mean_candle_size'], pair_config['margin'])
                print(f"Backtest results for {pair_name} - Buy:\n", stats)
        if pair_config.get('sell_prediction_file'):
            ohlc_data_with_predictions = load_and_align_data(ohlc_data, pair_config['sell_prediction_file'])
            if ohlc_data_with_predictions is not None:
                stats = run_backtest(ohlc_data_with_predictions, PredictionStrategy, pair_config['sell_risk_reward_ratio'], pair_name, 'Sell', pair_config['mean_candle_size'], pair_config['margin'])
                print(f"Backtest results for {pair_name} - Sell:\n", stats)

    mt5.shutdown()

if __name__ == "__main__":
    main()
# Out:
# Connected to MetaTrader 5
# Backtest results for EURUSD - Buy:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   71.036585
# Equity Final [$]                  6716.066508
# Equity Peak [$]                  10214.603493
# Return [%]                         -32.839335
# Buy & Hold Return [%]               -1.484055
# Return (Ann.) [%]                  -26.349837
# Volatility (Ann.) [%]                41.26189
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -48.781153
# Avg. Drawdown [%]                  -26.620178
# Max. Drawdown Duration      455 days 00:00:00
# Avg. Drawdown Duration      229 days 00:00:00
# # Trades                                   54
# Win Rate [%]                        31.481481
# Best Trade [%]                        2.02124
# Worst Trade [%]                     -0.897832
# Avg. Trade [%]                      -0.057884
# Max. Trade Duration          50 days 00:00:00
# Avg. Trade Duration          14 days 00:00:00
# Profit Factor                        0.913127
# Expectancy [%]                      -0.050877
# SQN                                 -0.847009
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# Backtest results for EURUSD - Sell:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   72.865854
# Equity Final [$]                 13418.587873
# Equity Peak [$]                  15544.738913
# Return [%]                          34.185879
# Buy & Hold Return [%]               -1.484055
# Return (Ann.) [%]                   25.347654
# Volatility (Ann.) [%]               72.453486
# Sharpe Ratio                         0.349847
# Sortino Ratio                        0.737691
# Calmar Ratio                         0.577614
# Max. Drawdown [%]                  -43.883406
# Avg. Drawdown [%]                  -14.493365
# Max. Drawdown Duration      192 days 00:00:00
# Avg. Drawdown Duration       48 days 00:00:00
# # Trades                                   75
# Win Rate [%]                        53.333333
# Best Trade [%]                        0.86004
# Worst Trade [%]                     -0.963844
# Avg. Trade [%]                       0.006668
# Max. Trade Duration          24 days 00:00:00
# Avg. Trade Duration           7 days 00:00:00
# Profit Factor                        1.024623
# Expectancy [%]                       0.010225
# SQN                                  0.526535
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for GBPUSD - Buy:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   78.658537
# Equity Final [$]                  11692.68447
# Equity Peak [$]                  16098.336479
# Return [%]                          16.926845
# Buy & Hold Return [%]                0.659925
# Return (Ann.) [%]                   12.765956
# Volatility (Ann.) [%]               78.871321
# Sharpe Ratio                         0.161858
# Sortino Ratio                        0.316377
# Calmar Ratio                         0.407453
# Max. Drawdown [%]                  -31.331097
# Avg. Drawdown [%]                  -16.147397
# Max. Drawdown Duration      205 days 00:00:00
# Avg. Drawdown Duration       45 days 00:00:00
# # Trades                                   72
# Win Rate [%]                        44.444444
# Best Trade [%]                       1.890161
# Worst Trade [%]                     -0.929126
# Avg. Trade [%]                       0.291182
# Max. Trade Duration          55 days 00:00:00
# Avg. Trade Duration          12 days 00:00:00
# Profit Factor                        1.629337
# Expectancy [%]                       0.299512
# SQN                                   0.23063
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for GBPUSD - Sell:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   78.658537
# Equity Final [$]                 15599.691058
# Equity Peak [$]                  20232.558204
# Return [%]                          55.996911
# Buy & Hold Return [%]                0.659925
# Return (Ann.) [%]                   40.724466
# Volatility (Ann.) [%]              105.187267
# Sharpe Ratio                         0.387162
# Sortino Ratio                        1.023361
# Calmar Ratio                          0.73162
# Max. Drawdown [%]                  -55.663386
# Avg. Drawdown [%]                  -12.734319
# Max. Drawdown Duration      395 days 00:00:00
# Avg. Drawdown Duration       64 days 00:00:00
# # Trades                                   95
# Win Rate [%]                        63.157895
# Best Trade [%]                       0.963986
# Worst Trade [%]                     -1.062522
# Avg. Trade [%]                       0.165942
# Max. Trade Duration          21 days 00:00:00
# Avg. Trade Duration           6 days 00:00:00
# Profit Factor                         1.50155
# Expectancy [%]                       0.169406
# SQN                                  0.628364
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for AUDUSD - Buy:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   71.036585
# Equity Final [$]                  7564.630068
# Equity Peak [$]                  10309.475684
# Return [%]                         -24.353699
# Buy & Hold Return [%]               -2.347739
# Return (Ann.) [%]                  -19.300012
# Volatility (Ann.) [%]               72.698153
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -61.482329
# Avg. Drawdown [%]                  -37.127982
# Max. Drawdown Duration      394 days 00:00:00
# Avg. Drawdown Duration      152 days 00:00:00
# # Trades                                   62
# Win Rate [%]                        37.096774
# Best Trade [%]                       2.821404
# Worst Trade [%]                     -1.273282
# Avg. Trade [%]                       0.146059
# Max. Trade Duration          66 days 00:00:00
# Avg. Trade Duration          14 days 00:00:00
# Profit Factor                         1.21364
# Expectancy [%]                       0.161771
# SQN                                 -0.420002
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for AUDUSD - Sell:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   60.670732
# Equity Final [$]                  7913.597773
# Equity Peak [$]                       10000.0
# Return [%]                         -20.864022
# Buy & Hold Return [%]               -2.347739
# Return (Ann.) [%]                  -16.454807
# Volatility (Ann.) [%]               71.349711
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -73.397819
# Avg. Drawdown [%]                  -73.397819
# Max. Drawdown Duration      450 days 00:00:00
# Avg. Drawdown Duration      450 days 00:00:00
# # Trades                                   63
# Win Rate [%]                        57.142857
# Best Trade [%]                       1.394426
# Worst Trade [%]                     -1.442775
# Avg. Trade [%]                       0.091128
# Max. Trade Duration          35 days 00:00:00
# Avg. Trade Duration           6 days 00:00:00
# Profit Factor                        1.177525
# Expectancy [%]                       0.098429
# SQN                                 -0.501941
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for USDCHF - Buy:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   67.682927
# Equity Final [$]                  9701.232615
# Equity Peak [$]                   13723.57842
# Return [%]                          -2.987674
# Buy & Hold Return [%]               -0.216805
# Return (Ann.) [%]                   -2.303452
# Volatility (Ann.) [%]               26.458994
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -37.612177
# Avg. Drawdown [%]                   -6.103437
# Max. Drawdown Duration      203 days 00:00:00
# Avg. Drawdown Duration       34 days 00:00:00
# # Trades                                   48
# Win Rate [%]                        41.666667
# Best Trade [%]                        1.90331
# Worst Trade [%]                     -1.144062
# Avg. Trade [%]                       0.200934
# Max. Trade Duration          36 days 00:00:00
# Avg. Trade Duration          12 days 00:00:00
# Profit Factor                        1.412407
# Expectancy [%]                       0.209166
# SQN                                 -0.096336
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# Backtest results for USDCHF - Sell:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   77.743902
# Equity Final [$]                 11473.241632
# Equity Peak [$]                  15568.118127
# Return [%]                          14.732416
# Buy & Hold Return [%]               -0.216805
# Return (Ann.) [%]                   11.136426
# Volatility (Ann.) [%]                43.02233
# Sharpe Ratio                         0.258852
# Sortino Ratio                        0.464231
# Calmar Ratio                          0.24258
# Max. Drawdown [%]                   -45.90824
# Avg. Drawdown [%]                  -12.148159
# Max. Drawdown Duration      308 days 00:00:00
# Avg. Drawdown Duration       63 days 00:00:00
# # Trades                                  109
# Win Rate [%]                        64.220183
# Best Trade [%]                       0.885875
# Worst Trade [%]                     -1.188379
# Avg. Trade [%]                       0.152108
# Max. Trade Duration          16 days 00:00:00
# Avg. Trade Duration           4 days 00:00:00
# Profit Factor                        1.447076
# Expectancy [%]                       0.155721
# SQN                                  0.348245
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for USDCAD - Buy:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   68.292683
# Equity Final [$]                 18995.840554
# Equity Peak [$]                  18995.840554
# Return [%]                          89.958406
# Buy & Hold Return [%]                5.802739
# Return (Ann.) [%]                   63.716065
# Volatility (Ann.) [%]               80.649408
# Sharpe Ratio                         0.790038
# Sortino Ratio                        2.214565
# Calmar Ratio                         1.864144
# Max. Drawdown [%]                  -34.179799
# Avg. Drawdown [%]                  -10.801933
# Max. Drawdown Duration      176 days 00:00:00
# Avg. Drawdown Duration       30 days 00:00:00
# # Trades                                   93
# Win Rate [%]                        60.215054
# Best Trade [%]                       0.863665
# Worst Trade [%]                     -0.667891
# Avg. Trade [%]                       0.123467
# Max. Trade Duration          21 days 00:00:00
# Avg. Trade Duration           5 days 00:00:00
# Profit Factor                        1.500105
# Expectancy [%]                       0.125361
# SQN                                  1.456823
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
# Backtest results for USDCAD - Sell:
#  Start                     2023-07-31 00:00:00
# End                       2024-11-01 00:00:00
# Duration                    459 days 00:00:00
# Exposure Time [%]                   96.341463
# Equity Final [$]                   4920.03902
# Equity Peak [$]                  10636.458728
# Return [%]                          -50.79961
# Buy & Hold Return [%]                5.802739
# Return (Ann.) [%]                  -42.011525
# Volatility (Ann.) [%]               31.503123
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -53.803777
# Avg. Drawdown [%]                  -46.189205
# Max. Drawdown Duration      311 days 00:00:00
# Avg. Drawdown Duration      226 days 00:00:00
# # Trades                                   45
# Win Rate [%]                        37.777778
# Best Trade [%]                       1.884554
# Worst Trade [%]                      -1.46964
# Avg. Trade [%]                      -0.125959
# Max. Trade Duration         108 days 00:00:00
# Avg. Trade Duration          31 days 00:00:00
# Profit Factor                        0.857251
# Expectancy [%]                      -0.114604
# SQN                                 -1.517353
# _strategy                  PredictionStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
